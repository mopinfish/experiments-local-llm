# %%
# !cd /content/repo && git pull origin feature/graphrag-experiment
# Out:
# /bin/bash: line 1: cd: /content/repo: No such file or directory

# %%
# !grep -A5 "GraphQueryResultオブジェクト" /content/repo/notebooks/graphrag_03_55testcase_comparison.ipynb
# Out:
# grep: /content/repo/notebooks/graphrag_03_55testcase_comparison.ipynb: No such file or directory
